# %%
from helpers.dataCollection.trackGeometry import TrackGeometryAnalyzer

TWA = TrackGeometryAnalyzer(2023, "Abu Dhabi")
TWA.calculate_track_geometry()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (268.53 MB) /Users/sidshah/Library/Caches/fastf1
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.4.4]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from helpers.dataCollection.trackGeometry import TrackGeometryAnalyzer
# ----> 3 TWA = TrackGeometryAnalyzer(2023, "Abu Dhabi")
#       4 TWA.calculate_track_geometry()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Projects/Boston University/Fall 2024/CS677 - Project - F1 Lap Time Prediction/helpers/dataCollection/trackGeometry.py:17, in TrackGeometryAnalyzer.__init__(self, year, grand_prix)
#       9 """
#      10 Initialize track geometry analysis for a specific race
#      11
#    (...)
#      14 - grand_prix: Name of the Grand Prix event
#      15 """
#      16 self.session = fastf1.get_session(year, grand_prix, 'Race')
# ---> 17 self.session.load()
#      18 self.driver = self.session.drivers[0]
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/core.py:1410, in Session.load(self, laps, telemetry, weather, messages, livedata)
#    1405 _logger.info(f"Loading data for "
#    1406              f"{self.event['EventName']} - {self.name}"
#    1407              f" [v{fastf1.__version__}]")
#    1409 self._load_session_info(livedata=livedata)
# -> 1410 self._load_drivers_results(livedata=livedata)
#    1412 if self.f1_api_support:
#    1413     if laps:
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/logger.py:151, in soft_exceptions.<locals>.__decorator.<locals>.__wrapped(*args, **kwargs)
#     149 if not LoggingManager.debug:
#     150     try:
# --> 151         return func(*args, **kwargs)
#     152     except Exception as exc:
#     153         logger.warning(msg)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/core.py:2178, in Session._load_drivers_results(self, livedata)
#    2175     driver_info_f1 = self._drivers_from_f1_api(livedata=livedata)
#    2176 if not self.event.is_testing():
#    2177     # load driver info from ergast
# -> 2178     driver_info_ergast = self._drivers_results_from_ergast(
#    2179         load_drivers=True, load_results=True
#    2180     )
#    2182 # set results from either source or join if both data is available
#    2183 # use driver info from F1 as primary source, only fall back to Ergast
#    2184 # if unavailable
#    2185 # use results from Ergast, if data is unavailable from F1 API
#    2187 no_driver_info_f1 = (driver_info_f1 is None) or driver_info_f1.empty
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/core.py:2323, in Session._drivers_results_from_ergast(self, load_drivers, load_results)
#    2316     else:
#    2317         # TODO: Use Ergast when it supports quali-like sprint results
#    2318         # return self._ergast.get_sprint_shootout_results(
#    2319         #     self.event.year, self.event.RoundNumber
#    2320         # )
#    2321         return None
# -> 2323 response = _get_data()
#    2325 if not response or not response.content:
#    2326     if (('Sprint' in session_name)
#    2327             and (session_name in self._QUALI_LIKE_SESSIONS)):
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/logger.py:151, in soft_exceptions.<locals>.__decorator.<locals>.__wrapped(*args, **kwargs)
#     149 if not LoggingManager.debug:
#     150     try:
# --> 151         return func(*args, **kwargs)
#     152     except Exception as exc:
#     153         logger.warning(msg)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/core.py:2298, in Session._drivers_results_from_ergast.<locals>._get_data()
#    2293 @soft_exceptions("ergast result data",
#    2294                  "Failed to load result data from Ergast!",
#    2295                  _logger)
#    2296 def _get_data():
#    2297     if session_name == 'Race':
# -> 2298         return self._ergast.get_race_results(
#    2299             self.event.year, self.event.RoundNumber
#    2300         )
#    2302     elif session_name == 'Qualifying':
#    2303         return self._ergast.get_qualifying_results(
#    2304             self.event.year, self.event.RoundNumber
#    2305         )
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/ergast/interface.py:1059, in Ergast.get_race_results(self, season, round, circuit, constructor, driver, grid_position, results_position, fastest_rank, status, result_type, auto_cast, limit, offset)
#    1017 """Get race results for one or multiple races.
#    1018
#    1019 See: https://ergast.com/mrd/methods/results/
#    (...)
#    1047     ``result_type`` parameter
#    1048 """
#    1049 selectors = {'season': season,
#    1050              'round': round,
#    1051              'circuit': circuit,
#    (...)
#    1056              'fastest_rank': fastest_rank,
#    1057              'status': status}
# -> 1059 return self._build_default_result(endpoint='results',
#    1060                                   table='RaceTable',
#    1061                                   category=API.Races_RaceResults,
#    1062                                   subcategory=API.RaceResults,
#    1063                                   result_type=result_type,
#    1064                                   auto_cast=auto_cast,
#    1065                                   limit=limit,
#    1066                                   offset=offset,
#    1067                                   selectors=selectors)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/ergast/interface.py:591, in Ergast._build_default_result(self, selectors, result_type, auto_cast, limit, **kwargs)
#     588 if limit is None:
#     589     limit = self._limit
# --> 591 return self._build_result(
#     592     result_type=result_type,
#     593     auto_cast=auto_cast,
#     594     limit=limit,
#     595     selectors=selectors,
#     596     **kwargs
#     597 )
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/ergast/interface.py:530, in Ergast._build_result(cls, endpoint, table, category, subcategory, result_type, auto_cast, limit, offset, selectors)
#     527 params = {'limit': limit, 'offset': offset}
#     529 # get response and split it into individual parts
# --> 530 resp = cls._get(url, params)
#     531 resp = resp['MRData']
#     532 body = resp.pop(table)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/ergast/interface.py:491, in Ergast._get(cls, url, params)
#     488 @classmethod
#     489 def _get(cls, url: str, params: dict) -> Union[dict, list]:
#     490     # request data from ergast and load the returned json data.
# --> 491     r = Cache.requests_get(url, headers=HEADERS, params=params,
#     492                            timeout=TIMEOUT)
#     493     if r.status_code == 200:
#     494         try:
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/req.py:303, in Cache.requests_get(cls, url, **kwargs)
#     300         return resp
#     302 cls._request_counter += 1
# --> 303 return cls._cached_request('GET', url, **kwargs)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/req.py:347, in Cache._cached_request(cls, method, url, **kwargs)
#     343 # catch TypeError raised by outdated requests-cache version if the
#     344 # cache was created with a newer version
#     345 # github.com/requests-cache/requests-cache/issues/973
#     346 try:
# --> 347     response = func(url, **kwargs)
#     348 except TypeError:
#     349     warnings.warn("You are using an outdated version of "
#     350                   "requests-cache. Consider upgrading.", UserWarning)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/requests_cache/session.py:127, in CacheMixin.get(self, url, params, **kwargs)
#     125 def get(self, url: str, params=None, **kwargs) -> AnyResponse:  # type: ignore
#     126     kwargs.setdefault('allow_redirects', True)
# --> 127     return self.request('GET', url, params=params, **kwargs)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/requests_cache/session.py:183, in CacheMixin.request(self, method, url, headers, expire_after, only_if_cached, refresh, force_refresh, *args, **kwargs)
#     181 headers = set_request_headers(headers, expire_after, only_if_cached, refresh, force_refresh)
#     182 with patch_form_boundary() if kwargs.get('files') else nullcontext():
# --> 183     return super().request(method, url, *args, headers=headers, **kwargs)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/requests_cache/session.py:228, in CacheMixin.send(self, request, expire_after, only_if_cached, refresh, force_refresh, **kwargs)
#     226     response = cached_response  # type: ignore
#     227 elif actions.resend_request:
# --> 228     response = self._resend(request, actions, cached_response, **kwargs)  # type: ignore
#     229 elif actions.send_request:
#     230     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/requests_cache/session.py:286, in CacheMixin._resend(self, request, actions, cached_response, **kwargs)
#     284 logger.debug('Stale response; attempting to re-send request')
#     285 try:
# --> 286     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#     287     if (
#     288         self.settings.stale_if_error
#     289         and response.status_code not in self.settings.allowable_codes
#     290     ):
#     291         response.raise_for_status()
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/requests_cache/session.py:254, in CacheMixin._send_and_cache(self, request, actions, cached_response, **kwargs)
#     250 """Send a request and cache the response, unless disabled by settings or headers.
#     251 If applicable, also handle conditional requests.
#     252 """
#     253 request = actions.update_request(request)
# --> 254 response = super().send(request, **kwargs)
#     255 actions.update_from_response(response)
#     257 if not actions.skip_write:
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/fastf1/req.py:136, in _SessionWithRateLimiting.send(self, request, **kwargs)
#     132         for lim in limiters:
#     133             # apply all defined limiters
#     134             lim.limit()
# --> 136 return super().send(request, **kwargs)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/f1/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/f1/lib/python3.12/http/client.py:1423, in HTTPConnection.getresponse(self)
#    1421 try:
#    1422     try:
# -> 1423         response.begin()
#    1424     except ConnectionError:
#    1425         self.close()
#
# File ~/miniconda3/envs/f1/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/miniconda3/envs/f1/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/f1/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/miniconda3/envs/f1/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/f1/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
